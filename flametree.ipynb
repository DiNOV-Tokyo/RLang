# %% [markdown]
# <a href="https://colab.research.google.com/github/DiNOV-Tokyo/RLang/blob/master/flametree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(datasets)
data("iris")
# ヒストグラムを確認


iris
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1   5.1          3.5         1.4          0.2         setosa
# 2   4.9          3.0         1.4          0.2         setosa
# 3   4.7          3.2         1.3          0.2         setosa
# 4   4.6          3.1         1.5          0.2         setosa
# 5   5.0          3.6         1.4          0.2         setosa
# 6   5.4          3.9         1.7          0.4         setosa
# 7   4.6          3.4         1.4          0.3         setosa
# 8   5.0          3.4         1.5          0.2         setosa
# 9   4.4          2.9         1.4          0.2         setosa
# 10  4.9          3.1         1.5          0.1         setosa
# 11  5.4          3.7         1.5          0.2         setosa
# 12  4.8          3.4         1.6          0.2         setosa
# 13  4.8          3.0         1.4          0.1         setosa
# 14  4.3          3.0         1.1          0.1         setosa
# ...

# %%
devtools::install_github("djnavarro/flametree")
# Out:
# ...
# purrr        (0.3.3 -> 0.3.4    ) [CRAN]
# ggforce      (NA    -> 0.3.1    ) [CRAN]
# paletteer    (NA    -> 1.1.0    ) [CRAN]
# glue         (1.3.2 -> 1.4.0    ) [CRAN]
# Rcpp         (1.0.4 -> 1.0.4.6  ) [CRAN]
# rprojroot    (1.2   -> 1.3-2    ) [CRAN]
# backports    (1.1.5 -> 1.1.6    ) [CRAN]
# processx     (3.4.1 -> 3.4.2    ) [CRAN]
# farver       (2.0.1 -> 2.0.3    ) [CRAN]
# isoband      (0.2.0 -> 0.2.1    ) [CRAN]
# gridExtra    (NA    -> 2.3      ) [CRAN]
# dichromat    (NA    -> 2.0-0    ) [CRAN]
# mapproj      (NA    -> 1.2.7    ) [CRAN]
# maps         (NA    -> 3.3.0    ) [CRAN]
# tweenr       (NA    -> 1.0.1    ) [CRAN]
# polyclip     (NA    -> 1.10-0   ) [CRAN]
# RcppEigen    (NA    -> 0.3.3.7.0) [CRAN]
# gameofthr... (NA    -> 1.0.2    ) [CRAN]
# ggthemes     (NA    -> 4.2.0    ) [CRAN]
# jcolors      (NA    -> 0.0.4    ) [CRAN]
# oompaBase    (NA    -> 3.2.9    ) [CRAN]
# harrypotter  (NA    -> 2.1.1    ) [CRAN]
# palr         (NA    -> 0.2.0    ) [CRAN]
# ...

# %% [markdown]
# This is my first R notebook.

# %%
library(flametree)

dat <- flametree_grow(seed = 4, time = 13) # data structure
img <- flametree_plot(tree = dat)          # ggplot object
plot(img)
# Out:
# plot without title
